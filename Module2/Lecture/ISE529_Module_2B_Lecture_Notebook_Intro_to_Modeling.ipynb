# %% [markdown]
# # Module 2B:  Introduction to Modeling

# %%
import numpy as np
import pandas as pd
advertising = pd.read_csv('Advertising.csv')
advertising
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
advertising.dtypes
# Out:
# TV           float64
# radio        float64
# newspaper    float64
# sales        float64
# dtype: object

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
plt.style.use('classic')

# %%
plt.scatter(x = advertising['TV'], y = advertising['sales'])
plt.title('Sales/TV Advertising Scatterplot')
plt.xlabel('TV Advertising')
plt.ylabel('Sales')
p1 = plt.show()

# %%
plt.scatter(x = advertising['radio'], y = advertising['sales'])
plt.title('Sales/Radio Advertising Scatterplot')
plt.xlabel('Radio Advertising')
plt.ylabel('Sales')
p2 = plt.show()

# %%
plt.scatter(x = advertising['newspaper'], y = advertising['sales'])
plt.title('Sales/Newspaper Advertising Scatterplot')
plt.xlabel('Newspaper Advertising')
plt.ylabel('Sales')
p3 = plt.show()

# %%
#  Create a three-panel plot

#  First of two sub-plots and set current axis
plt.subplot(3,1,1)  # (rows, columns, number)
plt.scatter(x = advertising['TV'], y = advertising['sales'])
plt.title('Sales/TV Advertising Scatterplot')
plt.xlabel('TV Advertising')
plt.ylabel('Sales')

#  Second sub-plot
plt.subplot(3,1,2)  # (rows, columns, number)
plt.scatter(x = advertising['radio'], y = advertising['sales'])
plt.title('Sales/Radio Advertising Scatterplot')
plt.xlabel('Radio Advertising')
plt.ylabel('Sales')

# Third sub-plot
plt.subplot(3,1,3)
plt.scatter(x = advertising['newspaper'], y = advertising['sales'])
plt.title('Sales/Newspaper Advertising Scatterplot')
plt.xlabel('Newspaper Advertising')
plt.ylabel('Sales')

fig.tight_layout()
plt.show()

# %%
import seaborn as sns
sns.scatterplot(data = advertising, x = "newspaper", y = "sales")
# Out:
# <AxesSubplot:xlabel='newspaper', ylabel='sales'>

# %%
advertising
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
income = pd.read_csv('Income2.csv')
income.head(10)
# Out:
#    Education   Seniority     Income
# 0  21.586207  113.103448  99.917173
# 1  18.275862  119.310345  92.579135
# 2  12.068966  100.689655  34.678727
# 3  17.034483  187.586207  78.702806
# 4  19.931034   20.000000  68.009922
# 5  18.275862   26.206897  71.504485
# 6  19.931034  150.344828  87.970467
# 7  21.172414   82.068966  79.811030
# 8  20.344828   88.275862  90.006327
# 9  10.000000  113.103448  45.655530

# %%
import seaborn as sns
sns.scatterplot(data=income1, x="Education", y="Income")
# Out:
# <AxesSubplot:xlabel='Education', ylabel='Income'>
